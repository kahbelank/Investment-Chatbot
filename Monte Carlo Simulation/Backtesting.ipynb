# %% [markdown]
# ### Aggressive

# %%
import os
import numpy as np
import pandas as pd
import yahoo_fin.stock_info as si
from datetime import datetime, timedelta
from MCPortfolioSimulator_LR import PortfolioSimulator

# List of assets to fetch data for
asset_list = ['COST', 'LLY', 'META', 'MRK', 'NVDA', '^TNX', '^TYX', 'WELL', 'O', 'CCI']

# Define the end date for fetching the data
end_date = datetime.now()

# Function to fetch historical data and calculate returns
def fetch_data_and_calculate_returns(period_years):
    start_date = end_date - timedelta(days=period_years * 365)
    all_assets_df = pd.DataFrame()

    for asset in asset_list:
        print(f"Fetching data for {asset}...")
        df = si.get_data(asset, start_date=start_date, end_date=end_date, index_as_date=True)
        
        df.rename(columns={
            'open': 'open', 'high': 'high', 'low': 'low', 'close': 'close',
            'adjclose': 'adj close', 'volume': 'volume'
        }, inplace=True)
        
        if all_assets_df.empty:
            all_assets_df = df
            all_assets_df.columns = pd.MultiIndex.from_product([[asset], all_assets_df.columns])
        else:
            df.columns = pd.MultiIndex.from_product([[asset], df.columns])
            all_assets_df = pd.concat([all_assets_df, df], axis=1)
    
    all_assets_df.dropna(inplace=True)
    historical_returns = {}
    for asset in asset_list:
        close_prices = all_assets_df[asset]['close']
        daily_returns = close_prices.pct_change().dropna()
        avg_daily_return = daily_returns.mean()
        annual_return = ((1 + avg_daily_return) ** 252 - 1) * 100
        historical_returns[asset] = annual_return

    return all_assets_df, historical_returns

# Function to run simulations and benchmark
def run_simulation_and_benchmark(period_years, initial_investment, weights):
    num_trading_days = period_years * 252
    all_assets_df, historical_returns = fetch_data_and_calculate_returns(period_years)

    sim_returns = PortfolioSimulator(
        portfolio_data=all_assets_df,
        annual_returns=historical_returns,
        weights=weights,
        num_simulation=500,
        num_trading_days=num_trading_days
    )

    cumulative_returns = sim_returns.calc_cumulative_return()
    sim_returns.plot_simulation()
    sim_returns.plot_distribution()

    summary = sim_returns.summarize_cumulative_return()
    print(summary)

    port_high_return = round(initial_investment * summary['95% CI Upper'], 2) 
    port_low_return = round(initial_investment * summary['95% CI Lower'], 2)

    print(f"There is a 95% chance that an initial investment of ${initial_investment} in the portfolio"
          f" over the next {period_years} years will end within the range of"
          f" ${port_low_return} and ${port_high_return}")

    # Historical Benchmarking
    historical_cumulative_return = {}
    for asset in asset_list:
        close_prices = all_assets_df[asset]['close']
        cumulative_return = (close_prices.iloc[-1] / close_prices.iloc[0]) - 1
        historical_cumulative_return[asset] = cumulative_return

    historical_portfolio_return = sum(historical_cumulative_return[asset] * weight for asset, weight in zip(asset_list, weights))
    print(f"Historical Portfolio Cumulative Return for {period_years} years: {historical_portfolio_return * 100:.2f}%")

    simulated_mean_return = summary['mean']
    print(f"Simulated Mean Cumulative Return for {period_years} years: {simulated_mean_return}")

    historical_volatility = {}
    for asset in asset_list:
        close_prices = all_assets_df[asset]['close']
        daily_returns = close_prices.pct_change().dropna()
        annual_volatility = daily_returns.std() * np.sqrt(252)
        historical_volatility[asset] = annual_volatility

    historical_portfolio_volatility = np.sqrt(sum((weight * historical_volatility[asset]) ** 2 for asset, weight in zip(asset_list, weights)))
    print(f"Historical Portfolio Volatility for {period_years} years: {historical_portfolio_volatility * 100:.2f}%")

    simulated_volatility = summary['std']
    print(f"Simulated Portfolio Volatility for {period_years} years: {simulated_volatility}")

# Define weights
weights = [0.1, 0.2, 0.02, 0.2, 0.2, 0.08, 0.17, 0.01, 0.01, 0.01]

# Initial investment
initial_investment = 100000

# Run simulations and benchmarks for different periods
for period in [2, 5, 10, 15]:
    print(f"\n--- Simulating for {period} years ---")
    run_simulation_and_benchmark(period, initial_investment, weights)
# Out:
# --- Simulating for 2 years ---
# Fetching data for COST...
# Fetching data for LLY...
# Fetching data for META...
# Fetching data for MRK...
# Fetching data for NVDA...
# Fetching data for ^TNX...
# Fetching data for ^TYX...
# Fetching data for WELL...
# Fetching data for O...
# Fetching data for CCI...
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# Running Monte Carlo simulation number 220.
# Running Monte Carlo simulation number 230.
# Running Monte Carlo simulation number 240.
# Running Monte Carlo simulation number 250.
# Running Monte Carlo simulation number 260.
# Running Monte Carlo simulation number 270.
# Running Monte Carlo simulation number 280.
# Running Monte Carlo simulation number 290.
# Running Monte Carlo simulation number 300.
# Running Monte Carlo simulation number 310.
# Running Monte Carlo simulation number 320.
# Running Monte Carlo simulation number 330.
# Running Monte Carlo simulation number 340.
# Running Monte Carlo simulation number 350.
# Running Monte Carlo simulation number 360.
# Running Monte Carlo simulation number 370.
# Running Monte Carlo simulation number 380.
# Running Monte Carlo simulation number 390.
# Running Monte Carlo simulation number 400.
# Running Monte Carlo simulation number 410.
# Running Monte Carlo simulation number 420.
# Running Monte Carlo simulation number 430.
# Running Monte Carlo simulation number 440.
# Running Monte Carlo simulation number 450.
# Running Monte Carlo simulation number 460.
# Running Monte Carlo simulation number 470.
# Running Monte Carlo simulation number 480.
# Running Monte Carlo simulation number 490.
# c:\Users\kahbe\Documents\GitHub\Investment-Chatbot\Monte Carlo Simulation\MCPortfolioSimulator_LR.py:97: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return metrics.append(ci_series)
# count           500.000000
# mean              2.827629
# std               0.484497
# min               1.743383
# 25%               2.471864
# 50%               2.801319
# 75%               3.120694
# max               4.736073
# 95% CI Lower      1.984036
# 95% CI Upper      3.780925
# Name: 504, dtype: float64
# There is a 95% chance that an initial investment of $100000 in the portfolio over the next 2 years will end within the range of $198403.6 and $378092.53
# Historical Portfolio Cumulative Return for 2 years: 181.63%
# Simulated Mean Cumulative Return for 2 years: 2.8276293076863586
# Historical Portfolio Volatility for 2 years: 13.71%
# Simulated Portfolio Volatility for 2 years: 0.4844968226109026
#
# --- Simulating for 5 years ---
# Fetching data for COST...
# Fetching data for LLY...
# Fetching data for META...
# Fetching data for MRK...
# Fetching data for NVDA...
# Fetching data for ^TNX...
# Fetching data for ^TYX...
# Fetching data for WELL...
# Fetching data for O...
# Fetching data for CCI...
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# Running Monte Carlo simulation number 220.
# Running Monte Carlo simulation number 230.
# Running Monte Carlo simulation number 240.
# Running Monte Carlo simulation number 250.
# Running Monte Carlo simulation number 260.
# Running Monte Carlo simulation number 270.
# Running Monte Carlo simulation number 280.
# Running Monte Carlo simulation number 290.
# Running Monte Carlo simulation number 300.
# Running Monte Carlo simulation number 310.
# Running Monte Carlo simulation number 320.
# Running Monte Carlo simulation number 330.
# Running Monte Carlo simulation number 340.
# Running Monte Carlo simulation number 350.
# Running Monte Carlo simulation number 360.
# Running Monte Carlo simulation number 370.
# Running Monte Carlo simulation number 380.
# Running Monte Carlo simulation number 390.
# Running Monte Carlo simulation number 400.
# Running Monte Carlo simulation number 410.
# Running Monte Carlo simulation number 420.
# Running Monte Carlo simulation number 430.
# Running Monte Carlo simulation number 440.
# Running Monte Carlo simulation number 450.
# Running Monte Carlo simulation number 460.
# Running Monte Carlo simulation number 470.
# Running Monte Carlo simulation number 480.
# Running Monte Carlo simulation number 490.
# c:\Users\kahbe\Documents\GitHub\Investment-Chatbot\Monte Carlo Simulation\MCPortfolioSimulator_LR.py:97: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return metrics.append(ci_series)
# count           500.000000
# mean              9.006093
# std               2.920380
# min               3.419328
# 25%               6.913281
# 50%               8.219046
# 75%              10.811131
# max              21.291443
# 95% CI Lower      4.673256
# 95% CI Upper     15.701563
# Name: 1260, dtype: float64
# There is a 95% chance that an initial investment of $100000 in the portfolio over the next 5 years will end within the range of $467325.61 and $1570156.34
# Historical Portfolio Cumulative Return for 5 years: 821.33%
# Simulated Mean Cumulative Return for 5 years: 9.006092920405015
# Historical Portfolio Volatility for 5 years: 16.06%
# Simulated Portfolio Volatility for 5 years: 2.920379862595377
#
# --- Simulating for 10 years ---
# Fetching data for COST...
# Fetching data for LLY...
# Fetching data for META...
# Fetching data for MRK...
# Fetching data for NVDA...
# Fetching data for ^TNX...
# Fetching data for ^TYX...
# Fetching data for WELL...
# Fetching data for O...
# Fetching data for CCI...
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# Running Monte Carlo simulation number 220.
# Running Monte Carlo simulation number 230.
# Running Monte Carlo simulation number 240.
# Running Monte Carlo simulation number 250.
# Running Monte Carlo simulation number 260.
# Running Monte Carlo simulation number 270.
# Running Monte Carlo simulation number 280.
# Running Monte Carlo simulation number 290.
# Running Monte Carlo simulation number 300.
# Running Monte Carlo simulation number 310.
# Running Monte Carlo simulation number 320.
# Running Monte Carlo simulation number 330.
# Running Monte Carlo simulation number 340.
# Running Monte Carlo simulation number 350.
# Running Monte Carlo simulation number 360.
# Running Monte Carlo simulation number 370.
# Running Monte Carlo simulation number 380.
# Running Monte Carlo simulation number 390.
# Running Monte Carlo simulation number 400.
# Running Monte Carlo simulation number 410.
# Running Monte Carlo simulation number 420.
# Running Monte Carlo simulation number 430.
# Running Monte Carlo simulation number 440.
# Running Monte Carlo simulation number 450.
# Running Monte Carlo simulation number 460.
# Running Monte Carlo simulation number 470.
# Running Monte Carlo simulation number 480.
# Running Monte Carlo simulation number 490.
# c:\Users\kahbe\Documents\GitHub\Investment-Chatbot\Monte Carlo Simulation\MCPortfolioSimulator_LR.py:97: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return metrics.append(ci_series)
# count           500.000000
# mean             24.376348
# std               9.494609
# min               7.809917
# 25%              17.587254
# 50%              22.636987
# 75%              29.440664
# max              66.764101
# 95% CI Lower     10.731204
# 95% CI Upper     45.521553
# Name: 2520, dtype: float64
# There is a 95% chance that an initial investment of $100000 in the portfolio over the next 10 years will end within the range of $1073120.4 and $4552155.35
# Historical Portfolio Cumulative Return for 10 years: 5345.20%
# Simulated Mean Cumulative Return for 10 years: 24.376348387695124
# Historical Portfolio Volatility for 10 years: 13.87%
# Simulated Portfolio Volatility for 10 years: 9.494608717466743
#
# --- Simulating for 15 years ---
# Fetching data for COST...
# Fetching data for LLY...
# Fetching data for META...
# Fetching data for MRK...
# Fetching data for NVDA...
# Fetching data for ^TNX...
# Fetching data for ^TYX...
# Fetching data for WELL...
# Fetching data for O...
# Fetching data for CCI...
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# Running Monte Carlo simulation number 220.
# Running Monte Carlo simulation number 230.
# Running Monte Carlo simulation number 240.
# Running Monte Carlo simulation number 250.
# Running Monte Carlo simulation number 260.
# Running Monte Carlo simulation number 270.
# Running Monte Carlo simulation number 280.
# Running Monte Carlo simulation number 290.
# Running Monte Carlo simulation number 300.
# Running Monte Carlo simulation number 310.
# Running Monte Carlo simulation number 320.
# Running Monte Carlo simulation number 330.
# Running Monte Carlo simulation number 340.
# Running Monte Carlo simulation number 350.
# Running Monte Carlo simulation number 360.
# Running Monte Carlo simulation number 370.
# Running Monte Carlo simulation number 380.
# Running Monte Carlo simulation number 390.
# Running Monte Carlo simulation number 400.
# Running Monte Carlo simulation number 410.
# Running Monte Carlo simulation number 420.
# Running Monte Carlo simulation number 430.
# Running Monte Carlo simulation number 440.
# Running Monte Carlo simulation number 450.
# Running Monte Carlo simulation number 460.
# Running Monte Carlo simulation number 470.
# Running Monte Carlo simulation number 480.
# Running Monte Carlo simulation number 490.
# c:\Users\kahbe\Documents\GitHub\Investment-Chatbot\Monte Carlo Simulation\MCPortfolioSimulator_LR.py:97: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return metrics.append(ci_series)
# count           500.000000
# mean             95.482898
# std              42.875096
# min              20.185829
# 25%              64.407882
# 50%              87.766369
# 75%             114.729010
# max             304.962455
# 95% CI Lower     41.689806
# 95% CI Upper    198.702651
# Name: 3780, dtype: float64
# There is a 95% chance that an initial investment of $100000 in the portfolio over the next 15 years will end within the range of $4168980.58 and $19870265.1
# Historical Portfolio Cumulative Return for 15 years: 8580.18%
# Simulated Mean Cumulative Return for 15 years: 95.48289792103324
# Historical Portfolio Volatility for 15 years: 13.16%
# Simulated Portfolio Volatility for 15 years: 42.875096393575035

# %% [markdown]
# ### Moderate

# %%
import os
import numpy as np
import pandas as pd
import yahoo_fin.stock_info as si
from datetime import datetime, timedelta
from MCPortfolioSimulator_LR import PortfolioSimulator

# List of assets to fetch data for
asset_list = ['COST', 'JPM', 'LLY', 'META', 'MRK', 'NVDA', 'PG', 'XOM', '^TNX', '^TYX', 'WELL', 'O', 'CCI']

# Define the end date for fetching the data
end_date = datetime.now()

# Function to fetch historical data and calculate returns
def fetch_data_and_calculate_returns(period_years):
    start_date = end_date - timedelta(days=period_years * 365)
    all_assets_df = pd.DataFrame()

    for asset in asset_list:
        print(f"Fetching data for {asset}...")
        df = si.get_data(asset, start_date=start_date, end_date=end_date, index_as_date=True)
        
        df.rename(columns={
            'open': 'open', 'high': 'high', 'low': 'low', 'close': 'close',
            'adjclose': 'adj close', 'volume': 'volume'
        }, inplace=True)
        
        if all_assets_df.empty:
            all_assets_df = df
            all_assets_df.columns = pd.MultiIndex.from_product([[asset], all_assets_df.columns])
        else:
            df.columns = pd.MultiIndex.from_product([[asset], df.columns])
            all_assets_df = pd.concat([all_assets_df, df], axis=1)
    
    all_assets_df.dropna(inplace=True)
    historical_returns = {}
    for asset in asset_list:
        close_prices = all_assets_df[asset]['close']
        daily_returns = close_prices.pct_change().dropna()
        avg_daily_return = daily_returns.mean()
        annual_return = ((1 + avg_daily_return) ** 252 - 1) * 100
        historical_returns[asset] = annual_return

    return all_assets_df, historical_returns

# Function to run simulations and benchmark
def run_simulation_and_benchmark(period_years, initial_investment, weights):
    num_trading_days = period_years * 252
    all_assets_df, historical_returns = fetch_data_and_calculate_returns(period_years)

    sim_returns = PortfolioSimulator(
        portfolio_data=all_assets_df,
        annual_returns=historical_returns,
        weights=weights,
        num_simulation=500,
        num_trading_days=num_trading_days
    )

    cumulative_returns = sim_returns.calc_cumulative_return()
    sim_returns.plot_simulation()
    sim_returns.plot_distribution()

    summary = sim_returns.summarize_cumulative_return()
    print(summary)

    port_high_return = round(initial_investment * summary['95% CI Upper'], 2) 
    port_low_return = round(initial_investment * summary['95% CI Lower'], 2)

    print(f"There is a 95% chance that an initial investment of ${initial_investment} in the portfolio"
          f" over the next {period_years} years will end within the range of"
          f" ${port_low_return} and ${port_high_return}")

    # Historical Benchmarking
    historical_cumulative_return = {}
    for asset in asset_list:
        close_prices = all_assets_df[asset]['close']
        cumulative_return = (close_prices.iloc[-1] / close_prices.iloc[0]) - 1
        historical_cumulative_return[asset] = cumulative_return

    historical_portfolio_return = sum(historical_cumulative_return[asset] * weight for asset, weight in zip(asset_list, weights))
    print(f"Historical Portfolio Cumulative Return for {period_years} years: {historical_portfolio_return * 100:.2f}%")

    simulated_mean_return = summary['mean']
    print(f"Simulated Mean Cumulative Return for {period_years} years: {simulated_mean_return}")

    historical_volatility = {}
    for asset in asset_list:
        close_prices = all_assets_df[asset]['close']
        daily_returns = close_prices.pct_change().dropna()
        annual_volatility = daily_returns.std() * np.sqrt(252)
        historical_volatility[asset] = annual_volatility

    historical_portfolio_volatility = np.sqrt(sum((weight * historical_volatility[asset]) ** 2 for asset, weight in zip(asset_list, weights)))
    print(f"Historical Portfolio Volatility for {period_years} years: {historical_portfolio_volatility * 100:.2f}%")

    simulated_volatility = summary['std']
    print(f"Simulated Portfolio Volatility for {period_years} years: {simulated_volatility}")

# Define weights
weights = [0.11, 0.05, 0.18, 0.01, 0.17, 0.09, 0.09, 0.01, 0.04, 0.2, 0.03, 0.01, 0.01]

# Initial investment
initial_investment = 45000

# Run simulations and benchmarks for different periods
for period in [2, 5, 10, 15]:
    print(f"\n--- Simulating for {period} years ---")
    run_simulation_and_benchmark(period, initial_investment, weights)
# Out:
# --- Simulating for 2 years ---
# Fetching data for COST...
# Fetching data for JPM...
# Fetching data for LLY...
# Fetching data for META...
# Fetching data for MRK...
# Fetching data for NVDA...
# Fetching data for PG...
# Fetching data for XOM...
# Fetching data for ^TNX...
# Fetching data for ^TYX...
# Fetching data for WELL...
# Fetching data for O...
# Fetching data for CCI...
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# Running Monte Carlo simulation number 220.
# Running Monte Carlo simulation number 230.
# Running Monte Carlo simulation number 240.
# Running Monte Carlo simulation number 250.
# Running Monte Carlo simulation number 260.
# Running Monte Carlo simulation number 270.
# Running Monte Carlo simulation number 280.
# Running Monte Carlo simulation number 290.
# Running Monte Carlo simulation number 300.
# Running Monte Carlo simulation number 310.
# Running Monte Carlo simulation number 320.
# Running Monte Carlo simulation number 330.
# Running Monte Carlo simulation number 340.
# Running Monte Carlo simulation number 350.
# Running Monte Carlo simulation number 360.
# Running Monte Carlo simulation number 370.
# Running Monte Carlo simulation number 380.
# Running Monte Carlo simulation number 390.
# Running Monte Carlo simulation number 400.
# Running Monte Carlo simulation number 410.
# Running Monte Carlo simulation number 420.
# Running Monte Carlo simulation number 430.
# Running Monte Carlo simulation number 440.
# Running Monte Carlo simulation number 450.
# Running Monte Carlo simulation number 460.
# Running Monte Carlo simulation number 470.
# Running Monte Carlo simulation number 480.
# Running Monte Carlo simulation number 490.
# c:\Users\kahbe\Documents\GitHub\Investment-Chatbot\Monte Carlo Simulation\MCPortfolioSimulator_LR.py:97: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return metrics.append(ci_series)
# count           500.000000
# mean              2.152152
# std               0.273634
# min               1.525398
# 25%               1.960919
# 50%               2.136320
# 75%               2.323618
# max               3.183561
# 95% CI Lower      1.689052
# 95% CI Upper      2.770810
# Name: 504, dtype: float64
# There is a 95% chance that an initial investment of $45000 in the portfolio over the next 2 years will end within the range of $76007.32 and $124686.46
# Historical Portfolio Cumulative Return for 2 years: 117.61%
# Simulated Mean Cumulative Return for 2 years: 2.152151639927232
# Historical Portfolio Volatility for 2 years: 9.79%
# Simulated Portfolio Volatility for 2 years: 0.27363370509243506
#
# --- Simulating for 5 years ---
# Fetching data for COST...
# Fetching data for JPM...
# Fetching data for LLY...
# Fetching data for META...
# Fetching data for MRK...
# Fetching data for NVDA...
# Fetching data for PG...
# Fetching data for XOM...
# Fetching data for ^TNX...
# Fetching data for ^TYX...
# Fetching data for WELL...
# Fetching data for O...
# Fetching data for CCI...
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# Running Monte Carlo simulation number 220.
# Running Monte Carlo simulation number 230.
# Running Monte Carlo simulation number 240.
# Running Monte Carlo simulation number 250.
# Running Monte Carlo simulation number 260.
# Running Monte Carlo simulation number 270.
# Running Monte Carlo simulation number 280.
# Running Monte Carlo simulation number 290.
# Running Monte Carlo simulation number 300.
# Running Monte Carlo simulation number 310.
# Running Monte Carlo simulation number 320.
# Running Monte Carlo simulation number 330.
# Running Monte Carlo simulation number 340.
# Running Monte Carlo simulation number 350.
# Running Monte Carlo simulation number 360.
# Running Monte Carlo simulation number 370.
# Running Monte Carlo simulation number 380.
# Running Monte Carlo simulation number 390.
# Running Monte Carlo simulation number 400.
# Running Monte Carlo simulation number 410.
# Running Monte Carlo simulation number 420.
# Running Monte Carlo simulation number 430.
# Running Monte Carlo simulation number 440.
# Running Monte Carlo simulation number 450.
# Running Monte Carlo simulation number 460.
# Running Monte Carlo simulation number 470.
# Running Monte Carlo simulation number 480.
# Running Monte Carlo simulation number 490.
# c:\Users\kahbe\Documents\GitHub\Investment-Chatbot\Monte Carlo Simulation\MCPortfolioSimulator_LR.py:97: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return metrics.append(ci_series)
# count           500.000000
# mean              5.368017
# std               1.330180
# min               2.546597
# 25%               4.384418
# 50%               5.275898
# 75%               6.173241
# max              10.624499
# 95% CI Lower      3.149090
# 95% CI Upper      8.139450
# Name: 1260, dtype: float64
# There is a 95% chance that an initial investment of $45000 in the portfolio over the next 5 years will end within the range of $141709.07 and $366275.23
# Historical Portfolio Cumulative Return for 5 years: 467.40%
# Simulated Mean Cumulative Return for 5 years: 5.368016519296637
# Historical Portfolio Volatility for 5 years: 12.92%
# Simulated Portfolio Volatility for 5 years: 1.3301798978171866
#
# --- Simulating for 10 years ---
# Fetching data for COST...
# Fetching data for JPM...
# Fetching data for LLY...
# Fetching data for META...
# Fetching data for MRK...
# Fetching data for NVDA...
# Fetching data for PG...
# Fetching data for XOM...
# Fetching data for ^TNX...
# Fetching data for ^TYX...
# Fetching data for WELL...
# Fetching data for O...
# Fetching data for CCI...
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# Running Monte Carlo simulation number 220.
# Running Monte Carlo simulation number 230.
# Running Monte Carlo simulation number 240.
# Running Monte Carlo simulation number 250.
# Running Monte Carlo simulation number 260.
# Running Monte Carlo simulation number 270.
# Running Monte Carlo simulation number 280.
# Running Monte Carlo simulation number 290.
# Running Monte Carlo simulation number 300.
# Running Monte Carlo simulation number 310.
# Running Monte Carlo simulation number 320.
# Running Monte Carlo simulation number 330.
# Running Monte Carlo simulation number 340.
# Running Monte Carlo simulation number 350.
# Running Monte Carlo simulation number 360.
# Running Monte Carlo simulation number 370.
# Running Monte Carlo simulation number 380.
# Running Monte Carlo simulation number 390.
# Running Monte Carlo simulation number 400.
# Running Monte Carlo simulation number 410.
# Running Monte Carlo simulation number 420.
# Running Monte Carlo simulation number 430.
# Running Monte Carlo simulation number 440.
# Running Monte Carlo simulation number 450.
# Running Monte Carlo simulation number 460.
# Running Monte Carlo simulation number 470.
# Running Monte Carlo simulation number 480.
# Running Monte Carlo simulation number 490.
# c:\Users\kahbe\Documents\GitHub\Investment-Chatbot\Monte Carlo Simulation\MCPortfolioSimulator_LR.py:97: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return metrics.append(ci_series)
# count           500.000000
# mean             11.120198
# std               3.413533
# min               4.147412
# 25%               8.810309
# 50%              10.680288
# 75%              13.072596
# max              26.607395
# 95% CI Lower      5.834660
# 95% CI Upper     19.094908
# Name: 2520, dtype: float64
# There is a 95% chance that an initial investment of $45000 in the portfolio over the next 10 years will end within the range of $262559.68 and $859270.85
# Historical Portfolio Cumulative Return for 10 years: 2605.48%
# Simulated Mean Cumulative Return for 10 years: 11.120198048150517
# Historical Portfolio Volatility for 10 years: 10.90%
# Simulated Portfolio Volatility for 10 years: 3.41353298909787
#
# --- Simulating for 15 years ---
# Fetching data for COST...
# Fetching data for JPM...
# Fetching data for LLY...
# Fetching data for META...
# Fetching data for MRK...
# Fetching data for NVDA...
# Fetching data for PG...
# Fetching data for XOM...
# Fetching data for ^TNX...
# Fetching data for ^TYX...
# Fetching data for WELL...
# Fetching data for O...
# Fetching data for CCI...
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# Running Monte Carlo simulation number 220.
# Running Monte Carlo simulation number 230.
# Running Monte Carlo simulation number 240.
# Running Monte Carlo simulation number 250.
# Running Monte Carlo simulation number 260.
# Running Monte Carlo simulation number 270.
# Running Monte Carlo simulation number 280.
# Running Monte Carlo simulation number 290.
# Running Monte Carlo simulation number 300.
# Running Monte Carlo simulation number 310.
# Running Monte Carlo simulation number 320.
# Running Monte Carlo simulation number 330.
# Running Monte Carlo simulation number 340.
# Running Monte Carlo simulation number 350.
# Running Monte Carlo simulation number 360.
# Running Monte Carlo simulation number 370.
# Running Monte Carlo simulation number 380.
# Running Monte Carlo simulation number 390.
# Running Monte Carlo simulation number 400.
# Running Monte Carlo simulation number 410.
# Running Monte Carlo simulation number 420.
# Running Monte Carlo simulation number 430.
# Running Monte Carlo simulation number 440.
# Running Monte Carlo simulation number 450.
# Running Monte Carlo simulation number 460.
# Running Monte Carlo simulation number 470.
# Running Monte Carlo simulation number 480.
# Running Monte Carlo simulation number 490.
# c:\Users\kahbe\Documents\GitHub\Investment-Chatbot\Monte Carlo Simulation\MCPortfolioSimulator_LR.py:97: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return metrics.append(ci_series)
# count           500.000000
# mean             34.417139
# std              12.341421
# min              12.605157
# 25%              25.461054
# 50%              32.503009
# 75%              40.767406
# max              91.186282
# 95% CI Lower     16.679152
# 95% CI Upper     64.706813
# Name: 3780, dtype: float64
# There is a 95% chance that an initial investment of $45000 in the portfolio over the next 15 years will end within the range of $750561.86 and $2911806.57
# Historical Portfolio Cumulative Return for 15 years: 4174.61%
# Simulated Mean Cumulative Return for 15 years: 34.41713875646549
# Historical Portfolio Volatility for 15 years: 10.38%
# Simulated Portfolio Volatility for 15 years: 12.341421151724317

# %% [markdown]
# ### Conservative

# %%
import os
import numpy as np
import pandas as pd
import yahoo_fin.stock_info as si
from datetime import datetime, timedelta
from MCPortfolioSimulator_LR import PortfolioSimulator

# List of assets to fetch data for
asset_list = ['ABBV', 'COST', 'JPM', 'LLY', 'META', 'MRK', 'NVDA', 'PG', 'XOM', '^TNX', '^TYX', 'WELL', 'O', 'CCI']

# Define the end date for fetching the data
end_date = datetime.now()

# Function to fetch historical data and calculate returns
def fetch_data_and_calculate_returns(period_years):
    start_date = end_date - timedelta(days=period_years * 365)
    all_assets_df = pd.DataFrame()

    for asset in asset_list:
        print(f"Fetching data for {asset}...")
        df = si.get_data(asset, start_date=start_date, end_date=end_date, index_as_date=True)
        
        df.rename(columns={
            'open': 'open', 'high': 'high', 'low': 'low', 'close': 'close',
            'adjclose': 'adj close', 'volume': 'volume'
        }, inplace=True)
        
        if all_assets_df.empty:
            all_assets_df = df
            all_assets_df.columns = pd.MultiIndex.from_product([[asset], all_assets_df.columns])
        else:
            df.columns = pd.MultiIndex.from_product([[asset], df.columns])
            all_assets_df = pd.concat([all_assets_df, df], axis=1)
    
    all_assets_df.dropna(inplace=True)
    historical_returns = {}
    for asset in asset_list:
        close_prices = all_assets_df[asset]['close']
        daily_returns = close_prices.pct_change().dropna()
        avg_daily_return = daily_returns.mean()
        annual_return = ((1 + avg_daily_return) ** 252 - 1) * 100
        historical_returns[asset] = annual_return

    return all_assets_df, historical_returns

# Function to run simulations and benchmark
def run_simulation_and_benchmark(period_years, initial_investment, weights):
    num_trading_days = period_years * 252
    all_assets_df, historical_returns = fetch_data_and_calculate_returns(period_years)

    sim_returns = PortfolioSimulator(
        portfolio_data=all_assets_df,
        annual_returns=historical_returns,
        weights=weights,
        num_simulation=500,
        num_trading_days=num_trading_days
    )

    cumulative_returns = sim_returns.calc_cumulative_return()
    sim_returns.plot_simulation()
    sim_returns.plot_distribution()

    summary = sim_returns.summarize_cumulative_return()
    print(summary)

    port_high_return = round(initial_investment * summary['95% CI Upper'], 2) 
    port_low_return = round(initial_investment * summary['95% CI Lower'], 2)

    print(f"There is a 95% chance that an initial investment of ${initial_investment} in the portfolio"
          f" over the next {period_years} years will end within the range of"
          f" ${port_low_return} and ${port_high_return}")

    # Historical Benchmarking
    historical_cumulative_return = {}
    for asset in asset_list:
        close_prices = all_assets_df[asset]['close']
        cumulative_return = (close_prices.iloc[-1] / close_prices.iloc[0]) - 1
        historical_cumulative_return[asset] = cumulative_return

    historical_portfolio_return = sum(historical_cumulative_return[asset] * weight for asset, weight in zip(asset_list, weights))
    print(f"Historical Portfolio Cumulative Return for {period_years} years: {historical_portfolio_return * 100:.2f}%")

    simulated_mean_return = summary['mean']
    print(f"Simulated Mean Cumulative Return for {period_years} years: {simulated_mean_return}")

    historical_volatility = {}
    for asset in asset_list:
        close_prices = all_assets_df[asset]['close']
        daily_returns = close_prices.pct_change().dropna()
        annual_volatility = daily_returns.std() * np.sqrt(252)
        historical_volatility[asset] = annual_volatility

    historical_portfolio_volatility = np.sqrt(sum((weight * historical_volatility[asset]) ** 2 for asset, weight in zip(asset_list, weights)))
    print(f"Historical Portfolio Volatility for {period_years} years: {historical_portfolio_volatility * 100:.2f}%")

    simulated_volatility = summary['std']
    print(f"Simulated Portfolio Volatility for {period_years} years: {simulated_volatility}")

# Define weights
weights = [0.01, 0.1, 0.04, 0.14, 0.01, 0.17, 0.07, 0.13, 0.02, 0.04, 0.2, 0.03, 0.03, 0.01]

# Initial investment
initial_investment = 31000

# Run simulations and benchmarks for different periods
for period in [2, 5, 10, 15]:
    print(f"\n--- Simulating for {period} years ---")
    run_simulation_and_benchmark(period, initial_investment, weights)
# Out:
# --- Simulating for 2 years ---
# Fetching data for ABBV...
# Fetching data for COST...
# Fetching data for JPM...
# Fetching data for LLY...
# Fetching data for META...
# Fetching data for MRK...
# Fetching data for NVDA...
# Fetching data for PG...
# Fetching data for XOM...
# Fetching data for ^TNX...
# Fetching data for ^TYX...
# Fetching data for WELL...
# Fetching data for O...
# Fetching data for CCI...
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# Running Monte Carlo simulation number 220.
# Running Monte Carlo simulation number 230.
# Running Monte Carlo simulation number 240.
# Running Monte Carlo simulation number 250.
# Running Monte Carlo simulation number 260.
# Running Monte Carlo simulation number 270.
# Running Monte Carlo simulation number 280.
# Running Monte Carlo simulation number 290.
# Running Monte Carlo simulation number 300.
# Running Monte Carlo simulation number 310.
# Running Monte Carlo simulation number 320.
# Running Monte Carlo simulation number 330.
# Running Monte Carlo simulation number 340.
# Running Monte Carlo simulation number 350.
# Running Monte Carlo simulation number 360.
# Running Monte Carlo simulation number 370.
# Running Monte Carlo simulation number 380.
# Running Monte Carlo simulation number 390.
# Running Monte Carlo simulation number 400.
# Running Monte Carlo simulation number 410.
# Running Monte Carlo simulation number 420.
# Running Monte Carlo simulation number 430.
# Running Monte Carlo simulation number 440.
# Running Monte Carlo simulation number 450.
# Running Monte Carlo simulation number 460.
# Running Monte Carlo simulation number 470.
# Running Monte Carlo simulation number 480.
# Running Monte Carlo simulation number 490.
# c:\Users\kahbe\Documents\GitHub\Investment-Chatbot\Monte Carlo Simulation\MCPortfolioSimulator_LR.py:97: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return metrics.append(ci_series)
# count           500.000000
# mean              1.954146
# std               0.214774
# min               1.388057
# 25%               1.799946
# 50%               1.940713
# 75%               2.083209
# max               2.782763
# 95% CI Lower      1.571278
# 95% CI Upper      2.399767
# Name: 504, dtype: float64
# There is a 95% chance that an initial investment of $31000 in the portfolio over the next 2 years will end within the range of $48709.63 and $74392.77
# Historical Portfolio Cumulative Return for 2 years: 98.18%
# Simulated Mean Cumulative Return for 2 years: 1.9541462797495757
# Historical Portfolio Volatility for 2 years: 8.86%
# Simulated Portfolio Volatility for 2 years: 0.21477445913370335
#
# --- Simulating for 5 years ---
# Fetching data for ABBV...
# Fetching data for COST...
# Fetching data for JPM...
# Fetching data for LLY...
# Fetching data for META...
# Fetching data for MRK...
# Fetching data for NVDA...
# Fetching data for PG...
# Fetching data for XOM...
# Fetching data for ^TNX...
# Fetching data for ^TYX...
# Fetching data for WELL...
# Fetching data for O...
# Fetching data for CCI...
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# Running Monte Carlo simulation number 220.
# Running Monte Carlo simulation number 230.
# Running Monte Carlo simulation number 240.
# Running Monte Carlo simulation number 250.
# Running Monte Carlo simulation number 260.
# Running Monte Carlo simulation number 270.
# Running Monte Carlo simulation number 280.
# Running Monte Carlo simulation number 290.
# Running Monte Carlo simulation number 300.
# Running Monte Carlo simulation number 310.
# Running Monte Carlo simulation number 320.
# Running Monte Carlo simulation number 330.
# Running Monte Carlo simulation number 340.
# Running Monte Carlo simulation number 350.
# Running Monte Carlo simulation number 360.
# Running Monte Carlo simulation number 370.
# Running Monte Carlo simulation number 380.
# Running Monte Carlo simulation number 390.
# Running Monte Carlo simulation number 400.
# Running Monte Carlo simulation number 410.
# Running Monte Carlo simulation number 420.
# Running Monte Carlo simulation number 430.
# Running Monte Carlo simulation number 440.
# Running Monte Carlo simulation number 450.
# Running Monte Carlo simulation number 460.
# Running Monte Carlo simulation number 470.
# Running Monte Carlo simulation number 480.
# Running Monte Carlo simulation number 490.
# c:\Users\kahbe\Documents\GitHub\Investment-Chatbot\Monte Carlo Simulation\MCPortfolioSimulator_LR.py:97: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return metrics.append(ci_series)
# count           500.000000
# mean              4.440303
# std               1.005620
# min               1.878799
# 25%               3.738140
# 50%               4.299026
# 75%               5.080126
# max               8.529750
# 95% CI Lower      2.798843
# 95% CI Upper      6.635193
# Name: 1260, dtype: float64
# There is a 95% chance that an initial investment of $31000 in the portfolio over the next 5 years will end within the range of $86764.14 and $205690.97
# Historical Portfolio Cumulative Return for 5 years: 378.68%
# Simulated Mean Cumulative Return for 5 years: 4.440303057899799
# Historical Portfolio Volatility for 5 years: 12.19%
# Simulated Portfolio Volatility for 5 years: 1.0056201987717097
#
# --- Simulating for 10 years ---
# Fetching data for ABBV...
# Fetching data for COST...
# Fetching data for JPM...
# Fetching data for LLY...
# Fetching data for META...
# Fetching data for MRK...
# Fetching data for NVDA...
# Fetching data for PG...
# Fetching data for XOM...
# Fetching data for ^TNX...
# Fetching data for ^TYX...
# Fetching data for WELL...
# Fetching data for O...
# Fetching data for CCI...
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# Running Monte Carlo simulation number 220.
# Running Monte Carlo simulation number 230.
# Running Monte Carlo simulation number 240.
# Running Monte Carlo simulation number 250.
# Running Monte Carlo simulation number 260.
# Running Monte Carlo simulation number 270.
# Running Monte Carlo simulation number 280.
# Running Monte Carlo simulation number 290.
# Running Monte Carlo simulation number 300.
# Running Monte Carlo simulation number 310.
# Running Monte Carlo simulation number 320.
# Running Monte Carlo simulation number 330.
# Running Monte Carlo simulation number 340.
# Running Monte Carlo simulation number 350.
# Running Monte Carlo simulation number 360.
# Running Monte Carlo simulation number 370.
# Running Monte Carlo simulation number 380.
# Running Monte Carlo simulation number 390.
# Running Monte Carlo simulation number 400.
# Running Monte Carlo simulation number 410.
# Running Monte Carlo simulation number 420.
# Running Monte Carlo simulation number 430.
# Running Monte Carlo simulation number 440.
# Running Monte Carlo simulation number 450.
# Running Monte Carlo simulation number 460.
# Running Monte Carlo simulation number 470.
# Running Monte Carlo simulation number 480.
# Running Monte Carlo simulation number 490.
# c:\Users\kahbe\Documents\GitHub\Investment-Chatbot\Monte Carlo Simulation\MCPortfolioSimulator_LR.py:97: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return metrics.append(ci_series)
# count           500.000000
# mean              8.566959
# std               2.526550
# min               3.384353
# 25%               6.796013
# 50%               8.298559
# 75%               9.726646
# max              20.078662
# 95% CI Lower      4.561563
# 95% CI Upper     14.723555
# Name: 2520, dtype: float64
# There is a 95% chance that an initial investment of $31000 in the portfolio over the next 10 years will end within the range of $141408.44 and $456430.2
# Historical Portfolio Cumulative Return for 10 years: 2054.15%
# Simulated Mean Cumulative Return for 10 years: 8.566959471149291
# Historical Portfolio Volatility for 10 years: 10.23%
# Simulated Portfolio Volatility for 10 years: 2.5265495210187177
#
# --- Simulating for 15 years ---
# Fetching data for ABBV...
# Fetching data for COST...
# Fetching data for JPM...
# Fetching data for LLY...
# Fetching data for META...
# Fetching data for MRK...
# Fetching data for NVDA...
# Fetching data for PG...
# Fetching data for XOM...
# Fetching data for ^TNX...
# Fetching data for ^TYX...
# Fetching data for WELL...
# Fetching data for O...
# Fetching data for CCI...
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# Running Monte Carlo simulation number 220.
# Running Monte Carlo simulation number 230.
# Running Monte Carlo simulation number 240.
# Running Monte Carlo simulation number 250.
# Running Monte Carlo simulation number 260.
# Running Monte Carlo simulation number 270.
# Running Monte Carlo simulation number 280.
# Running Monte Carlo simulation number 290.
# Running Monte Carlo simulation number 300.
# Running Monte Carlo simulation number 310.
# Running Monte Carlo simulation number 320.
# Running Monte Carlo simulation number 330.
# Running Monte Carlo simulation number 340.
# Running Monte Carlo simulation number 350.
# Running Monte Carlo simulation number 360.
# Running Monte Carlo simulation number 370.
# Running Monte Carlo simulation number 380.
# Running Monte Carlo simulation number 390.
# Running Monte Carlo simulation number 400.
# Running Monte Carlo simulation number 410.
# Running Monte Carlo simulation number 420.
# Running Monte Carlo simulation number 430.
# Running Monte Carlo simulation number 440.
# Running Monte Carlo simulation number 450.
# Running Monte Carlo simulation number 460.
# Running Monte Carlo simulation number 470.
# Running Monte Carlo simulation number 480.
# Running Monte Carlo simulation number 490.
# c:\Users\kahbe\Documents\GitHub\Investment-Chatbot\Monte Carlo Simulation\MCPortfolioSimulator_LR.py:97: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return metrics.append(ci_series)
# count           500.000000
# mean             24.005488
# std               8.019888
# min               8.434313
# 25%              18.359737
# 50%              23.263964
# 75%              27.946404
# max              59.687020
# 95% CI Lower     11.375933
# 95% CI Upper     43.641703
# Name: 3780, dtype: float64
# There is a 95% chance that an initial investment of $31000 in the portfolio over the next 15 years will end within the range of $352653.91 and $1352892.78
# Historical Portfolio Cumulative Return for 15 years: 3065.20%
# Simulated Mean Cumulative Return for 15 years: 24.00548803580271
# Historical Portfolio Volatility for 15 years: 9.83%
# Simulated Portfolio Volatility for 15 years: 8.019887844160426
